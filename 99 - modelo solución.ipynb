# %%
# Importando librerias

import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
# Importando datos y visualizando

ruta_archivo = r"C:\Users\EDER\Desktop\DCS UDEA\Inteligencia artificial\train.csv"

df_datos = pd.read_csv(ruta_archivo)

df_datos.head()
# Out:
#        ID  PERIODO         ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0  904256    20212                  ENFERMERIA                 BOGOTÁ
# 1  645256    20212                     DERECHO              ATLANTICO
# 2  308367    20203       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3  470353    20195  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4  989032    20212                  PSICOLOGIA              ANTIOQUIA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET                 FAMI_EDUCACIONPADRE  \
# ...

# %%
# Verificando tamaño del dataframe

print(df_datos.shape)
# Out:
# (692500, 21)

# %%
# Verificando valores NA de los datos

k = df_datos.isna().sum()
k[k!=0]
# Out:
# ESTU_VALORMATRICULAUNIVERSIDAD     6287
# ESTU_HORASSEMANATRABAJA           30857
# FAMI_ESTRATOVIVIENDA              32137
# FAMI_TIENEINTERNET                26629
# FAMI_EDUCACIONPADRE               23178
# FAMI_TIENELAVADORA                39773
# FAMI_TIENEAUTOMOVIL               43623
# ESTU_PAGOMATRICULAPROPIO           6498
# FAMI_TIENECOMPUTADOR              38103
# FAMI_TIENEINTERNET.1              26629
# FAMI_EDUCACIONMADRE               23664
# dtype: int64

# %%
# Verificando variables en el dataframe

df_datos.columns
# Out:
# Index(['ID', 'PERIODO', 'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_HORASSEMANATRABAJA',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONPADRE',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_PRIVADO_LIBERTAD',
#        'ESTU_PAGOMATRICULAPROPIO', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENEINTERNET.1', 'FAMI_EDUCACIONMADRE', 'RENDIMIENTO_GLOBAL',
#        'coef_1', 'coef_2', 'coef_3', 'coef_4'],
#       dtype='object')

# %%
# Verificando tipo de dato en variables

for c in df_datos.columns:
    print ("%20s"%c, df_datos[c].dtype)
# Out:
#                   ID int64
#              PERIODO int64
#  ESTU_PRGM_ACADEMICO object
# ESTU_PRGM_DEPARTAMENTO object
# ESTU_VALORMATRICULAUNIVERSIDAD object
# ESTU_HORASSEMANATRABAJA object
# FAMI_ESTRATOVIVIENDA object
#   FAMI_TIENEINTERNET object
#  FAMI_EDUCACIONPADRE object
#   FAMI_TIENELAVADORA object
#  FAMI_TIENEAUTOMOVIL object
# ESTU_PRIVADO_LIBERTAD object
# ESTU_PAGOMATRICULAPROPIO object
# FAMI_TIENECOMPUTADOR object
# FAMI_TIENEINTERNET.1 object
#  FAMI_EDUCACIONMADRE object
#   RENDIMIENTO_GLOBAL object
#               coef_1 float64
#               coef_2 float64
#               coef_3 float64
#               coef_4 float64

# %%
# Inspeccionando variables numericas

df_datos._get_numeric_data().describe().T
# Out:
#             count           mean            std      min         25%  \
# ID       692500.0  494606.130576  285585.209455      1.0  247324.750
# PERIODO  692500.0   20198.366679      10.535037  20183.0   20195.000
# coef_1   692500.0       0.268629       0.122130      0.0       0.203
# coef_2   692500.0       0.259996       0.093480      0.0       0.212
# coef_3   692500.0       0.262087       0.058862      0.0       0.254
# coef_4   692500.0       0.262903       0.067944      0.0       0.255
#
#                 50%         75%         max
# ID       494564.500  741782.500  989286.000
# PERIODO   20195.000   20203.000   20213.000
# coef_1        0.240       0.314       0.657
# coef_2        0.271       0.309       0.487
# coef_3        0.276       0.293       0.320
# coef_4        0.285       0.303       0.332

# %%
# Inspeccionando variables categoricas

ccols = [i for i in df_datos.columns if not i in df_datos._get_numeric_data()]
print (ccols)
# Out:
# ['ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO', 'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_HORASSEMANATRABAJA', 'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONPADRE', 'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_PRIVADO_LIBERTAD', 'ESTU_PAGOMATRICULAPROPIO', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET.1', 'FAMI_EDUCACIONMADRE', 'RENDIMIENTO_GLOBAL']

# %%
# Inspeccionando datos en variables categoricas

for c in ccols:
    print ("%10s"%c, np.unique(df_datos[c].dropna()))
# Out:
# ESTU_PRGM_ACADEMICO ['3°  CICLO PROFESIONAL NEGOCIOS INTERNACIONALES'
#  'ACTIVIDAD FISICA Y DEPORTE' 'ACUICULTURA' 'ADMINISTRACION'
#  'ADMINISTRACION  FINANCIERA' 'ADMINISTRACION & SERVICIO'
#  'ADMINISTRACION AERONAUTICA' 'ADMINISTRACION AGROPECUARIA'
#  'ADMINISTRACION AMBIENTAL'
#  'ADMINISTRACION AMBIENTAL Y DE LOS RECURSOS NATURALES'
#  'ADMINISTRACION BANCARIA Y FINANCIERA' 'ADMINISTRACION COMERCIAL'
#  'ADMINISTRACION COMERCIAL Y DE MERCADEO'
#  'ADMINISTRACION DE COMERCIO EXTERIOR' 'ADMINISTRACION DE EMPRESAS'
#  'ADMINISTRACION DE EMPRESAS  Y  GESTION AMBIENTAL'
#  'ADMINISTRACION DE EMPRESAS AGROINDUSTRIALES'
#  'ADMINISTRACION DE EMPRESAS AGROPECUARIAS'
#  'ADMINISTRACION DE EMPRESAS COMERCIALES'
#  'ADMINISTRACION DE EMPRESAS EN TELECOMUNICACIONES'
#  'ADMINISTRACION DE EMPRESAS TURISTICA'
#  'ADMINISTRACION DE EMPRESAS TURISTICAS'
#  'ADMINISTRACION DE EMPRESAS TURISTICAS Y HOTELERAS'
#  'ADMINISTRACION DE EMPRESAS TURÍSTICAS Y HOTELERAS'
# ...

# %%
# Identificando cantidades por categoria en la variable objetivo

c="RENDIMIENTO_GLOBAL"
df_datos[c].value_counts()
# Out:
# RENDIMIENTO_GLOBAL
# alto          175619
# bajo          172987
# medio-bajo    172275
# medio-alto    171619
# Name: count, dtype: int64

# %%
# Verificano valores duplicados en dataframe

df_datos = df_datos.drop_duplicates()
df_datos.tail()
# Out:
#             ID  PERIODO                  ESTU_PRGM_ACADEMICO  \
# 692495   25096    20195                             BIOLOGIA
# 692496  754213    20212                           PSICOLOGIA
# 692497  504185    20183  ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 692498  986620    20195                           PSICOLOGIA
# 692499  933374    20195                           PSICOLOGIA
#
#        ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 692495             LA GUAJIRA         Entre 500 mil y menos de 1 millón
# 692496        NORTE SANTANDER  Entre 2.5 millones y menos de 4 millones
# 692497                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
# 692498                 TOLIMA  Entre 2.5 millones y menos de 4 millones
# 692499              ANTIOQUIA  Entre 5.5 millones y menos de 7 millones
#
#        ESTU_HORASSEMANATRABAJA FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 692495     Entre 11 y 20 horas            Estrato 2                 Si
# ...

# %%
# Eliminando columnas que se han considerado irrelevantes para el analisis

df_datos = df_datos.drop(columns = "ESTU_PRGM_ACADEMICO")
df_datos = df_datos.drop(columns = "FAMI_TIENEINTERNET.1")

print(df_datos.shape)
# Out:
# (692500, 19)

# %%
# Remplazando valores N, S con No, Si en variable ESTU_PRIVADO_LIBERTAD y visualizando

df_datos["ESTU_PRIVADO_LIBERTAD"] = df_datos["ESTU_PRIVADO_LIBERTAD"].str.replace("Noo", "N")
df_datos["ESTU_PRIVADO_LIBERTAD"] = df_datos["ESTU_PRIVADO_LIBERTAD"].str.replace("No", "N")
df_datos["ESTU_PRIVADO_LIBERTAD"] = df_datos["ESTU_PRIVADO_LIBERTAD"].str.replace("Si", "S")
df_datos["ESTU_PRIVADO_LIBERTAD"] = df_datos["ESTU_PRIVADO_LIBERTAD"].str.replace("N", "No")
df_datos["ESTU_PRIVADO_LIBERTAD"] = df_datos["ESTU_PRIVADO_LIBERTAD"].str.replace("S", "Si")
df_datos.head()

# %%
# Separando variable objetivo de predictores

Y = df_datos.RENDIMIENTO_GLOBAL

X = df_datos.drop(["RENDIMIENTO_GLOBAL"], axis = 1)

# %%
# Importando herramienta de libreria y definiendo un SimpleImputer con estrategia el valor mas frecuente

from sklearn.impute import SimpleImputer

my_Imputer = SimpleImputer(strategy = "most_frequent")

# %%
# Importando herramienta de libreria y realizando tranformacion de valores en columnas para eliminar datos faltantes en dataframe para prediciones

from sklearn.compose import make_column_transformer

ct = make_column_transformer((my_Imputer,["ESTU_VALORMATRICULAUNIVERSIDAD"]),
                             (my_Imputer,["ESTU_HORASSEMANATRABAJA"]),
                             (my_Imputer,["FAMI_ESTRATOVIVIENDA"]),
                             (my_Imputer,["FAMI_TIENEINTERNET"]),
                             (my_Imputer,["FAMI_EDUCACIONPADRE"]),
                             (my_Imputer,["FAMI_TIENELAVADORA"]),
                             (my_Imputer,["FAMI_TIENEAUTOMOVIL"]),
                             (my_Imputer,["ESTU_PAGOMATRICULAPROPIO"]),
                             (my_Imputer,["FAMI_TIENECOMPUTADOR"]),
                             (my_Imputer,["FAMI_EDUCACIONMADRE"]), remainder="passthrough")

# %%
# Visualizando y realizando ajustes a salida de tranformacion de valores en columnas para eliminar datos faltantes

ct.set_output(transform="pandas")

X = ct.fit_transform(X)

X
# Out:
#        simpleimputer-1__ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0             Entre 5.5 millones y menos de 7 millones
# 1             Entre 2.5 millones y menos de 4 millones
# 2             Entre 2.5 millones y menos de 4 millones
# 3             Entre 4 millones y menos de 5.5 millones
# 4             Entre 2.5 millones y menos de 4 millones
# ...                                                ...
# 692495               Entre 500 mil y menos de 1 millón
# 692496        Entre 2.5 millones y menos de 4 millones
# 692497          Entre 1 millón y menos de 2.5 millones
# 692498        Entre 2.5 millones y menos de 4 millones
# 692499        Entre 5.5 millones y menos de 7 millones
#
#        simpleimputer-2__ESTU_HORASSEMANATRABAJA  \
# 0                             Menos de 10 horas
# 1                                             0
# 2                               Más de 30 horas
# 3                                             0
# 4                           Entre 21 y 30 horas
# ...

# %%
# Ajustando nombre de columnas trasformadas y organizando en dataframe de predictores

X = X.rename(columns={'simpleimputer-1__ESTU_VALORMATRICULAUNIVERSIDAD': 'ESTU_VALORMATRICULAUNIVERSIDAD',
                      'simpleimputer-2__ESTU_HORASSEMANATRABAJA': 'ESTU_HORASSEMANATRABAJA',
                      'simpleimputer-3__FAMI_ESTRATOVIVIENDA': 'FAMI_ESTRATOVIVIENDA',
                      'simpleimputer-4__FAMI_TIENEINTERNET': 'FAMI_TIENEINTERNET',
                      'simpleimputer-5__FAMI_EDUCACIONPADRE': 'FAMI_EDUCACIONPADRE',
                      'simpleimputer-6__FAMI_TIENELAVADORA': 'FAMI_TIENELAVADORA',
                      'simpleimputer-7__FAMI_TIENEAUTOMOVIL': 'FAMI_TIENEAUTOMOVIL',
                      'simpleimputer-8__ESTU_PAGOMATRICULAPROPIO': 'ESTU_PAGOMATRICULAPROPIO',
                      'simpleimputer-9__FAMI_TIENECOMPUTADOR': 'FAMI_TIENECOMPUTADOR',
                      'simpleimputer-10__FAMI_EDUCACIONMADRE': 'FAMI_EDUCACIONMADRE',
                      'remainder__ID': 'ID',
                      'remainder__PERIODO': 'PERIODO',
                      'remainder__ESTU_PRGM_DEPARTAMENTO': 'ESTU_PRGM_DEPARTAMENTO',
                      'remainder__ESTU_PRIVADO_LIBERTAD': 'ESTU_PRIVADO_LIBERTAD',
                      'remainder__coef_1': 'coef_1',
                      'remainder__coef_2': 'coef_2',
                      'remainder__coef_3': 'coef_3',
                      'remainder__coef_4': 'coef_4'
                      })

# Definir el nuevo orden de las columnas
new_order = ['ID', 'PERIODO', 'ESTU_PRGM_DEPARTAMENTO',
       'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_HORASSEMANATRABAJA',
       'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONPADRE',
       'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_PRIVADO_LIBERTAD',
       'ESTU_PAGOMATRICULAPROPIO', 'FAMI_TIENECOMPUTADOR',
       'FAMI_EDUCACIONMADRE', 'coef_1', 'coef_2',
       'coef_3', 'coef_4']

# Reordenar el DataFrame
X = X.reindex(columns=new_order)

X
# Out:
#             ID  PERIODO ESTU_PRGM_DEPARTAMENTO  \
# 0       904256    20212                 BOGOTÁ
# 1       645256    20212              ATLANTICO
# 2       308367    20203                 BOGOTÁ
# 3       470353    20195              SANTANDER
# 4       989032    20212              ANTIOQUIA
# ...        ...      ...                    ...
# 692495   25096    20195             LA GUAJIRA
# 692496  754213    20212        NORTE SANTANDER
# 692497  504185    20183                 BOGOTÁ
# 692498  986620    20195                 TOLIMA
# 692499  933374    20195              ANTIOQUIA
#
#                   ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0       Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1       Entre 2.5 millones y menos de 4 millones                       0
# 2       Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3       Entre 4 millones y menos de 5.5 millones                       0
# ...

# %%
# Calcular la moda de la columna y reemplazando el valor específico por la moda en variable FAMI_ESTRATOVIVIENDA en dataframe de predictores

moda = X['FAMI_ESTRATOVIVIENDA'].mode()[0]


X['FAMI_ESTRATOVIVIENDA'] = X['FAMI_ESTRATOVIVIENDA'].replace('Sin Estrato', moda)

# %%
# Calcular la moda de la columna y reemplazando el valor específico por la moda en variable FAMI_EDUCACIONPADRE en dataframe de predictores

moda = X['FAMI_EDUCACIONPADRE'].mode()[0]


X['FAMI_EDUCACIONPADRE'] = X['FAMI_EDUCACIONPADRE'].replace('No sabe', moda)

# %%
# Calcular la moda de la columna y reemplazando el valor específico por la moda en variable FAMI_EDUCACIONMADRE en dataframe de predictores

moda = X['FAMI_EDUCACIONMADRE'].mode()[0]


X['FAMI_EDUCACIONMADRE'] = X['FAMI_EDUCACIONMADRE'].replace('No sabe', moda)

# %%
# Cambiando de string a numero en variables categoricas y binarias para predictores

# ESTU_PRGM_DEPARTAMENTO ['AMAZONAS' 'ANTIOQUIA' 'ARAUCA' 'ATLANTICO' 'BOGOTÁ' 'BOLIVAR' 'BOYACA'
#  'CALDAS' 'CAQUETA' 'CASANARE' 'CAUCA' 'CESAR' 'CHOCO' 'CORDOBA'
#  'CUNDINAMARCA' 'GUAVIARE' 'HUILA' 'LA GUAJIRA' 'MAGDALENA' 'META'
#  'NARIÑO' 'NORTE SANTANDER' 'PUTUMAYO' 'QUINDIO' 'RISARALDA' 'SAN ANDRES'
#  'SANTANDER' 'SUCRE' 'TOLIMA' 'VALLE' 'VAUPES']

DEPARTAMENTO = {'AMAZONAS':1, 'ANTIOQUIA':2, 'ARAUCA':3, 'ATLANTICO':4, 'BOGOTÁ':5, 'BOLIVAR':6, 'BOYACA':7,
 'CALDAS':8, 'CAQUETA':9, 'CASANARE':10, 'CAUCA':11, 'CESAR':12, 'CHOCO':13, 'CORDOBA':14,
 'CUNDINAMARCA':15, 'GUAVIARE':16, 'HUILA':17, 'LA GUAJIRA':18, 'MAGDALENA':19, 'META':20,
 'NARIÑO':21, 'NORTE SANTANDER':22, 'PUTUMAYO':23, 'QUINDIO':24, 'RISARALDA':25, 'SAN ANDRES':26,
 'SANTANDER':27, 'SUCRE':28, 'TOLIMA':29, 'VALLE':30, 'VAUPES':31}

X["ESTU_PRGM_DEPARTAMENTO"]=X["ESTU_PRGM_DEPARTAMENTO"].map(DEPARTAMENTO)


# ESTU_VALORMATRICULAUNIVERSIDAD ['Entre 1 millón y menos de 2.5 millones'
#  'Entre 2.5 millones y menos de 4 millones'
#  'Entre 4 millones y menos de 5.5 millones'
#  'Entre 5.5 millones y menos de 7 millones'
#  'Entre 500 mil y menos de 1 millón' 'Menos de 500 mil'
#  'Más de 7 millones' 'No pagó matrícula']

VALORMATRICULA = {'Entre 1 millón y menos de 2.5 millones':2.49,
 'Entre 2.5 millones y menos de 4 millones':3.99,
 'Entre 4 millones y menos de 5.5 millones':5.49,
 'Entre 5.5 millones y menos de 7 millones':6.99, 'Entre 500 mil y menos de 1 millón':0.99, 'Menos de 500 mil':0.49,
 'Más de 7 millones':7, 'No pagó matrícula':0}

X["ESTU_VALORMATRICULAUNIVERSIDAD"]=X["ESTU_VALORMATRICULAUNIVERSIDAD"].map(VALORMATRICULA)


# ESTU_HORASSEMANATRABAJA ['0' 'Entre 11 y 20 horas' 'Entre 21 y 30 horas' 'Menos de 10 horas'
#  'Más de 30 horas']

HORASSEMANA = {'0':0, 'Entre 11 y 20 horas':20, 'Entre 21 y 30 horas':30, 'Menos de 10 horas':9,
 'Más de 30 horas':31}

X["ESTU_HORASSEMANATRABAJA"]=X["ESTU_HORASSEMANATRABAJA"].map(HORASSEMANA)


# FAMI_ESTRATOVIVIENDA ['Estrato 1' 'Estrato 2' 'Estrato 3' 'Estrato 4' 'Estrato 5' 'Estrato 6'
#  'Sin Estrato']

ESTRATO = {'Estrato 1':1, 'Estrato 2':2, 'Estrato 3':3, 'Estrato 4':4, 'Estrato 5':5, 'Estrato 6':6}

X["FAMI_ESTRATOVIVIENDA"]=X["FAMI_ESTRATOVIVIENDA"].map(ESTRATO)


# FAMI_TIENEINTERNET ['No' 'Si']

INTERNET = {'No':0, 'Si':1}
X["FAMI_TIENEINTERNET"]=X["FAMI_TIENEINTERNET"].map(INTERNET)


# FAMI_EDUCACIONPADRE ['Educación profesional completa' 'Educación profesional incompleta'
#  'Ninguno' 'No Aplica' 'No sabe' 'Postgrado' 'Primaria completa'
#  'Primaria incompleta' 'Secundaria (Bachillerato) completa'
#  'Secundaria (Bachillerato) incompleta' 'Técnica o tecnológica completa'
#  'Técnica o tecnológica incompleta']

EDUCACIONPADRE = {'Educación profesional completa':8, 'Educación profesional incompleta':7,
 'Ninguno':0, 'Postgrado':9, 'Primaria completa':2,
 'Primaria incompleta':1, 'Secundaria (Bachillerato) completa':4,
 'Secundaria (Bachillerato) incompleta':3, 'Técnica o tecnológica completa':6,
 'Técnica o tecnológica incompleta':5, 'No Aplica':0}

X["FAMI_EDUCACIONPADRE"]=X["FAMI_EDUCACIONPADRE"].map(EDUCACIONPADRE)


#FAMI_TIENELAVADORA ['No' 'Si']

TIENELAVADORA = {'No':0, 'Si':1}
X["FAMI_TIENELAVADORA"]=X["FAMI_TIENELAVADORA"].map(TIENELAVADORA)


#FAMI_TIENEAUTOMOVIL ['No' 'Si']

TIENEAUTOMOVIL = {'No':0, 'Si':1}
X["FAMI_TIENEAUTOMOVIL"]=X["FAMI_TIENEAUTOMOVIL"].map(TIENEAUTOMOVIL)


#ESTU_PRIVADO_LIBERTAD ['N0' 'Si']

ESTU_PRIVADO = {'No':0, 'Si':1}
X["ESTU_PRIVADO_LIBERTAD"]=X["ESTU_PRIVADO_LIBERTAD"].map(ESTU_PRIVADO)


#ESTU_PAGOMATRICULAPROPIO ['No' 'Si']

PAGOMATRICULA = {'No':0, 'Si':1}
X["ESTU_PAGOMATRICULAPROPIO"]=X["ESTU_PAGOMATRICULAPROPIO"].map(PAGOMATRICULA)


#FAMI_TIENECOMPUTADOR ['No' 'Si']

TIENECOMPUTADOR = {'No':0, 'Si':1}
X["FAMI_TIENECOMPUTADOR"]=X["FAMI_TIENECOMPUTADOR"].map(TIENECOMPUTADOR)


# FAMI_EDUCACIONMADRE ['Educación profesional completa' 'Educación profesional incompleta'
#  'Ninguno' 'No Aplica' 'No sabe' 'Postgrado' 'Primaria completa'
#  'Primaria incompleta' 'Secundaria (Bachillerato) completa'
#  'Secundaria (Bachillerato) incompleta' 'Técnica o tecnológica completa'
#  'Técnica o tecnológica incompleta']

EDUCACIONMADRE = {'Educación profesional completa':8, 'Educación profesional incompleta':7,
 'Ninguno':0, 'Postgrado':9, 'Primaria completa':2,
 'Primaria incompleta':1, 'Secundaria (Bachillerato) completa':4,
 'Secundaria (Bachillerato) incompleta':3, 'Técnica o tecnológica completa':6,
 'Técnica o tecnológica incompleta':5, 'No Aplica':0}

X["FAMI_EDUCACIONMADRE"]=X["FAMI_EDUCACIONMADRE"].map(EDUCACIONMADRE)

# %%
# Cambiando de string a numero en variables categoricas para variable objetivo

RENDIMIENTO = {'alto':3, 'bajo':0, 'medio-alto':2, 'medio-bajo':1}
Y=Y.map(RENDIMIENTO)

# %%
# Importando herramienta y dividiendo datos para entrenamiento y test

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.9, test_size = 0.1)

# %%
# Importando herramientas, definiendo modelo HistGradientBoostingClassifier e identificando score

from sklearn.ensemble import HistGradientBoostingClassifier

HGBC = HistGradientBoostingClassifier(learning_rate=0.1, max_iter=700, max_leaf_nodes=31, max_depth=17, min_samples_leaf=20, l2_regularization=0.0, max_features=1.0, max_bins=225).fit(X_train, Y_train)
HGBC.score(X_test, Y_test)
# Out:
# 0.41584115523465703

# %%
# Importando datos para prediccion de Kagle y visualizando

ruta_archivo_2 = r"C:\Users\EDER\Desktop\DCS UDEA\Inteligencia artificial\test.csv"

df_datos_2 = pd.read_csv(ruta_archivo_2)
df_datos_2
# Out:
#             ID  PERIODO                     ESTU_PRGM_ACADEMICO  \
# 0       550236    20183                          TRABAJO SOCIAL
# 1        98545    20203  ADMINISTRACION COMERCIAL Y DE MERCADEO
# 2       499179    20212                  INGENIERIA MECATRONICA
# 3       782980    20195                      CONTADURIA PUBLICA
# 4       785185    20212              ADMINISTRACION DE EMPRESAS
# ...        ...      ...                                     ...
# 296781  496981    20195              ADMINISTRACION DE EMPRESAS
# 296782  209415    20183                                 DERECHO
# 296783  239074    20212                                 DERECHO
# 296784  963852    20195                  INGENIERIA AERONAUTICA
# 296785  792650    20212                   INGENIERIA INDUSTRIAL
#
#        ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0                     BOLIVAR                          Menos de 500 mil
# ...

# %%
# Verificando valores NA de los datos Kagle

k = df_datos_2.isna().sum()
k[k!=0]
# Out:
# ESTU_VALORMATRICULAUNIVERSIDAD     2723
# ESTU_HORASSEMANATRABAJA           13379
# FAMI_ESTRATOVIVIENDA              13795
# FAMI_TIENEINTERNET                11539
# FAMI_EDUCACIONPADRE                9993
# FAMI_TIENELAVADORA                17259
# FAMI_TIENEAUTOMOVIL               18918
# ESTU_PAGOMATRICULAPROPIO           2807
# FAMI_TIENECOMPUTADOR              16439
# FAMI_TIENEINTERNET.1              11539
# FAMI_EDUCACIONMADRE               10223
# dtype: int64

# %%
# Eliminando columnas que se han considerado irrelevantes para el analisis de dataframe Kagle

df_datos_2 = df_datos_2.drop(columns = "ESTU_PRGM_ACADEMICO")
df_datos_2 = df_datos_2.drop(columns = "FAMI_TIENEINTERNET.1")

# %%
# Remplazando valores N, S con No, Si en variable ESTU_PRIVADO_LIBERTAD dataframe Kagle

df_datos_2["ESTU_PRIVADO_LIBERTAD"] = df_datos_2["ESTU_PRIVADO_LIBERTAD"].str.replace("Noo", "N")
df_datos_2["ESTU_PRIVADO_LIBERTAD"] = df_datos_2["ESTU_PRIVADO_LIBERTAD"].str.replace("No", "N")
df_datos_2["ESTU_PRIVADO_LIBERTAD"] = df_datos_2["ESTU_PRIVADO_LIBERTAD"].str.replace("Si", "S")
df_datos_2["ESTU_PRIVADO_LIBERTAD"] = df_datos_2["ESTU_PRIVADO_LIBERTAD"].str.replace("N", "No")
df_datos_2["ESTU_PRIVADO_LIBERTAD"] = df_datos_2["ESTU_PRIVADO_LIBERTAD"].str.replace("S", "Si")
df_datos_2.head()
# Out:
#        ID  PERIODO ESTU_PRGM_DEPARTAMENTO  \
# 0  550236    20183                BOLIVAR
# 1   98545    20203              ANTIOQUIA
# 2  499179    20212                 BOGOTÁ
# 3  782980    20195                  SUCRE
# 4  785185    20212              ATLANTICO
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0                          Menos de 500 mil       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
# 2    Entre 1 millón y menos de 2.5 millones                       0
# 3    Entre 1 millón y menos de 2.5 millones     Entre 21 y 30 horas
# 4  Entre 2.5 millones y menos de 4 millones     Entre 11 y 20 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 0            Estrato 3                 Si
# 1            Estrato 2                 Si
# 2            Estrato 3                 Si
# 3            Estrato 1                 No
# 4            Estrato 2                 Si
#
# ...

# %%
# Visualizando y realizando ajustes a salida de tranformacion de valores en columnas para eliminar datos faltantes dataframe Kagle

X2 = df_datos_2
X2 = ct.fit_transform(X2)
X2
# Out:
#        simpleimputer-1__ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0                                     Menos de 500 mil
# 1             Entre 2.5 millones y menos de 4 millones
# 2               Entre 1 millón y menos de 2.5 millones
# 3               Entre 1 millón y menos de 2.5 millones
# 4             Entre 2.5 millones y menos de 4 millones
# ...                                                ...
# 296781        Entre 2.5 millones y menos de 4 millones
# 296782          Entre 1 millón y menos de 2.5 millones
# 296783        Entre 2.5 millones y menos de 4 millones
# 296784        Entre 5.5 millones y menos de 7 millones
# 296785                               No pagó matrícula
#
#        simpleimputer-2__ESTU_HORASSEMANATRABAJA  \
# 0                             Menos de 10 horas
# 1                           Entre 21 y 30 horas
# 2                                             0
# 3                           Entre 21 y 30 horas
# 4                           Entre 11 y 20 horas
# ...

# %%
# Ajustando nombre de columnas trasformadas y organizando en dataframe de predictores dataframe Kagle

X2 = X2.rename(columns={'simpleimputer-1__ESTU_VALORMATRICULAUNIVERSIDAD': 'ESTU_VALORMATRICULAUNIVERSIDAD',
                      'simpleimputer-2__ESTU_HORASSEMANATRABAJA': 'ESTU_HORASSEMANATRABAJA',
                      'simpleimputer-3__FAMI_ESTRATOVIVIENDA': 'FAMI_ESTRATOVIVIENDA',
                      'simpleimputer-4__FAMI_TIENEINTERNET': 'FAMI_TIENEINTERNET',
                      'simpleimputer-5__FAMI_EDUCACIONPADRE': 'FAMI_EDUCACIONPADRE',
                      'simpleimputer-6__FAMI_TIENELAVADORA': 'FAMI_TIENELAVADORA',
                      'simpleimputer-7__FAMI_TIENEAUTOMOVIL': 'FAMI_TIENEAUTOMOVIL',
                      'simpleimputer-8__ESTU_PAGOMATRICULAPROPIO': 'ESTU_PAGOMATRICULAPROPIO',
                      'simpleimputer-9__FAMI_TIENECOMPUTADOR': 'FAMI_TIENECOMPUTADOR',
                      'simpleimputer-10__FAMI_EDUCACIONMADRE': 'FAMI_EDUCACIONMADRE',
                      'remainder__ID': 'ID',
                      'remainder__PERIODO': 'PERIODO',
                      'remainder__ESTU_PRGM_DEPARTAMENTO': 'ESTU_PRGM_DEPARTAMENTO',
                      'remainder__ESTU_PRIVADO_LIBERTAD': 'ESTU_PRIVADO_LIBERTAD',
                      'remainder__coef_1': 'coef_1',
                      'remainder__coef_2': 'coef_2',
                      'remainder__coef_3': 'coef_3',
                      'remainder__coef_4': 'coef_4'
                      })

# Definir el nuevo orden de las columnas
new_order = ['ID', 'PERIODO', 'ESTU_PRGM_DEPARTAMENTO',
       'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_HORASSEMANATRABAJA',
       'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONPADRE',
       'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_PRIVADO_LIBERTAD',
       'ESTU_PAGOMATRICULAPROPIO', 'FAMI_TIENECOMPUTADOR',
       'FAMI_EDUCACIONMADRE', 'coef_1', 'coef_2',
       'coef_3', 'coef_4']

# Reordenar el DataFrame
X2 = X2.reindex(columns=new_order)

# %%
# Calcular la moda de la columna y reemplazando el valor específico por la moda en variable FAMI_ESTRATOVIVIENDA en dataframe de predictores Kagle

moda = X2['FAMI_ESTRATOVIVIENDA'].mode()[0]

X2['FAMI_ESTRATOVIVIENDA'] = X2['FAMI_ESTRATOVIVIENDA'].replace('Sin Estrato', moda)

# %%
# Calcular la moda de la columna y reemplazando el valor específico por la moda en variable FAMI_EDUCACIONPADRE en dataframe de predictores Kagle

moda = X2['FAMI_EDUCACIONPADRE'].mode()[0]

X2['FAMI_EDUCACIONPADRE'] = X2['FAMI_EDUCACIONPADRE'].replace('No sabe', moda)

# %%
# # Calcular la moda de la columna y reemplazando el valor específico por la moda en variable FAMI_EDUCACIONMADRE en dataframe de predictores Kagle

moda = X2['FAMI_EDUCACIONMADRE'].mode()[0]

X2['FAMI_EDUCACIONMADRE'] = X2['FAMI_EDUCACIONMADRE'].replace('No sabe', moda)

# %%
# Cambiando de string a numero en variables categoricas y binarias dataframe Kagle

# ESTU_PRGM_DEPARTAMENTO ['AMAZONAS' 'ANTIOQUIA' 'ARAUCA' 'ATLANTICO' 'BOGOTÁ' 'BOLIVAR' 'BOYACA'
#  'CALDAS' 'CAQUETA' 'CASANARE' 'CAUCA' 'CESAR' 'CHOCO' 'CORDOBA'
#  'CUNDINAMARCA' 'GUAVIARE' 'HUILA' 'LA GUAJIRA' 'MAGDALENA' 'META'
#  'NARIÑO' 'NORTE SANTANDER' 'PUTUMAYO' 'QUINDIO' 'RISARALDA' 'SAN ANDRES'
#  'SANTANDER' 'SUCRE' 'TOLIMA' 'VALLE' 'VAUPES']

DEPARTAMENTO = {'AMAZONAS': 1, 'ANTIOQUIA': 2, 'ARAUCA': 3, 'ATLANTICO': 4, 'BOGOTÁ': 5, 'BOLIVAR': 6, 'BOYACA': 7,
                'CALDAS': 8, 'CAQUETA': 9, 'CASANARE': 10, 'CAUCA': 11, 'CESAR': 12, 'CHOCO': 13, 'CORDOBA': 14,
                'CUNDINAMARCA': 15, 'GUAVIARE': 16, 'HUILA': 17, 'LA GUAJIRA': 18, 'MAGDALENA': 19, 'META': 20,
                'NARIÑO': 21, 'NORTE SANTANDER': 22, 'PUTUMAYO': 23, 'QUINDIO': 24, 'RISARALDA': 25, 'SAN ANDRES': 26,
                'SANTANDER': 27, 'SUCRE': 28, 'TOLIMA': 29, 'VALLE': 30, 'VAUPES': 31}

X2["ESTU_PRGM_DEPARTAMENTO"] = X2["ESTU_PRGM_DEPARTAMENTO"].map(DEPARTAMENTO)

# ESTU_VALORMATRICULAUNIVERSIDAD ['Entre 1 millón y menos de 2.5 millones'
#  'Entre 2.5 millones y menos de 4 millones'
#  'Entre 4 millones y menos de 5.5 millones'
#  'Entre 5.5 millones y menos de 7 millones'
#  'Entre 500 mil y menos de 1 millón' 'Menos de 500 mil'
#  'Más de 7 millones' 'No pagó matrícula']

VALORMATRICULA = {'Entre 1 millón y menos de 2.5 millones': 2.49,
                  'Entre 2.5 millones y menos de 4 millones': 3.99,
                  'Entre 4 millones y menos de 5.5 millones': 5.49,
                  'Entre 5.5 millones y menos de 7 millones': 6.99, 'Entre 500 mil y menos de 1 millón': 0.99,
                  'Menos de 500 mil': 0.49,
                  'Más de 7 millones': 7, 'No pagó matrícula': 0}

X2["ESTU_VALORMATRICULAUNIVERSIDAD"] = X2["ESTU_VALORMATRICULAUNIVERSIDAD"].map(VALORMATRICULA)

# ESTU_HORASSEMANATRABAJA ['0' 'Entre 11 y 20 horas' 'Entre 21 y 30 horas' 'Menos de 10 horas'
#  'Más de 30 horas']

HORASSEMANA = {'0': 0, 'Entre 11 y 20 horas': 20, 'Entre 21 y 30 horas': 30, 'Menos de 10 horas': 9,
               'Más de 30 horas': 31}

X2["ESTU_HORASSEMANATRABAJA"] = X2["ESTU_HORASSEMANATRABAJA"].map(HORASSEMANA)

# FAMI_ESTRATOVIVIENDA ['Estrato 1' 'Estrato 2' 'Estrato 3' 'Estrato 4' 'Estrato 5' 'Estrato 6'
#  'Sin Estrato']

ESTRATO = {'Estrato 1': 1, 'Estrato 2': 2, 'Estrato 3': 3, 'Estrato 4': 4, 'Estrato 5': 5, 'Estrato 6': 6,
           'Sin Estrato': 1}

X2["FAMI_ESTRATOVIVIENDA"] = X2["FAMI_ESTRATOVIVIENDA"].map(ESTRATO)

# FAMI_TIENEINTERNET ['No' 'Si']

INTERNET = {'No': 0, 'Si': 1}
X2["FAMI_TIENEINTERNET"] = X2["FAMI_TIENEINTERNET"].map(INTERNET)

# FAMI_EDUCACIONPADRE ['Educación profesional completa' 'Educación profesional incompleta'
#  'Ninguno' 'No Aplica' 'No sabe' 'Postgrado' 'Primaria completa'
#  'Primaria incompleta' 'Secundaria (Bachillerato) completa'
#  'Secundaria (Bachillerato) incompleta' 'Técnica o tecnológica completa'
#  'Técnica o tecnológica incompleta']

EDUCACIONPADRE = {'Educación profesional completa': 8, 'Educación profesional incompleta': 7,
                  'Ninguno': 0, 'Postgrado': 9, 'Primaria completa': 2,
                  'Primaria incompleta': 1, 'Secundaria (Bachillerato) completa': 4,
                  'Secundaria (Bachillerato) incompleta': 3, 'Técnica o tecnológica completa': 6,
                  'Técnica o tecnológica incompleta': 5, 'No Aplica': 0, 'No sabe': 0}

X2["FAMI_EDUCACIONPADRE"] = X2["FAMI_EDUCACIONPADRE"].map(EDUCACIONPADRE)

#FAMI_TIENELAVADORA ['No' 'Si']

TIENELAVADORA = {'No': 0, 'Si': 1}
X2["FAMI_TIENELAVADORA"] = X2["FAMI_TIENELAVADORA"].map(TIENELAVADORA)

#FAMI_TIENEAUTOMOVIL ['No' 'Si']

TIENEAUTOMOVIL = {'No': 0, 'Si': 1}
X2["FAMI_TIENEAUTOMOVIL"] = X2["FAMI_TIENEAUTOMOVIL"].map(TIENEAUTOMOVIL)

#ESTU_PRIVADO_LIBERTAD ['N0' 'Si']

ESTU_PRIVADO = {'No': 0, 'Si': 1}
X2["ESTU_PRIVADO_LIBERTAD"] = X2["ESTU_PRIVADO_LIBERTAD"].map(ESTU_PRIVADO)

#ESTU_PAGOMATRICULAPROPIO ['No' 'Si']

PAGOMATRICULA = {'No': 0, 'Si': 1}
X2["ESTU_PAGOMATRICULAPROPIO"] = X2["ESTU_PAGOMATRICULAPROPIO"].map(PAGOMATRICULA)

#FAMI_TIENECOMPUTADOR ['No' 'Si']

TIENECOMPUTADOR = {'No': 0, 'Si': 1}
X2["FAMI_TIENECOMPUTADOR"] = X2["FAMI_TIENECOMPUTADOR"].map(TIENECOMPUTADOR)

# FAMI_EDUCACIONMADRE ['Educación profesional completa' 'Educación profesional incompleta'
#  'Ninguno' 'No Aplica' 'No sabe' 'Postgrado' 'Primaria completa'
#  'Primaria incompleta' 'Secundaria (Bachillerato) completa'
#  'Secundaria (Bachillerato) incompleta' 'Técnica o tecnológica completa'
#  'Técnica o tecnológica incompleta']

EDUCACIONMADRE = {'Educación profesional completa': 8, 'Educación profesional incompleta': 7,
                  'Ninguno': 0, 'Postgrado': 9, 'Primaria completa': 2,
                  'Primaria incompleta': 1, 'Secundaria (Bachillerato) completa': 4,
                  'Secundaria (Bachillerato) incompleta': 3, 'Técnica o tecnológica completa': 6,
                  'Técnica o tecnológica incompleta': 5, 'No Aplica': 0, 'No sabe': 0}

X2["FAMI_EDUCACIONMADRE"] = X2["FAMI_EDUCACIONMADRE"].map(EDUCACIONMADRE)

# %%
# Reentrenando el modelo y realizando la predicion a partir de los datos Kaggle

HGBC.fit(X, Y)
SC_predictions = HGBC.predict(X2)
SC_predictions
# Out:
# array([3, 2, 1, ..., 2, 3, 3], dtype=int64)

# %%
# Visualizando y definiendo el dataframe para enviar solucion a Kaggle

submission = pd.DataFrame([X2.ID, pd.Series(SC_predictions, name="RENDIMIENTO_GLOBAL")]).T
submission
# Out:
#             ID  RENDIMIENTO_GLOBAL
# 0       550236                   3
# 1        98545                   2
# 2       499179                   1
# 3       782980                   0
# 4       785185                   0
# ...        ...                 ...
# 296781  496981                   1
# 296782  209415                   3
# 296783  239074                   2
# 296784  963852                   3
# 296785  792650                   3
#
# [296786 rows x 2 columns]

# %%
# Visualizando y reasignando valores a variable RENDIMIENTO_GLOBAL

RENDIMIENTO = {3:'alto', 0:'bajo', 2:'medio-alto', 1:'medio-bajo'}

#submission['RENDIMIENTO_GLOBAL'] = submission['RENDIMIENTO_GLOBAL'].replace(RENDIMIENTO)
submission['RENDIMIENTO_GLOBAL'] = submission['RENDIMIENTO_GLOBAL'].map(RENDIMIENTO)
submission
# Out:
#             ID RENDIMIENTO_GLOBAL
# 0       550236               alto
# 1        98545         medio-alto
# 2       499179         medio-bajo
# 3       782980               bajo
# 4       785185               bajo
# ...        ...                ...
# 296781  496981         medio-bajo
# 296782  209415               alto
# 296783  239074         medio-alto
# 296784  963852               alto
# 296785  792650               alto
#
# [296786 rows x 2 columns]

# %%
# Creando el archivo CSV para enviar a Kaggle

submission.to_csv("submission.csv", index=False)
